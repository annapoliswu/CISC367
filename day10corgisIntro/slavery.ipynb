# %% [markdown]
# # Set Up
# Importing original data from https://www.aeaweb.org/articles?id=10.1257/aer.20131483

# %%
import pandas as pd
import numpy as np

xl = pd.ExcelFile("data.xlsx")
xl.sheet_names
df = xl.parse("Sheet1")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14713 entries, 0 to 14712
# Data columns (total 71 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   ID number                 14713 non-null  int64
#  1   Conveyance                14713 non-null  int64
#  2   Page                      14713 non-null  object
#  3   Researcher                14713 non-null  object
#  4   Notary First Name         14713 non-null  object
#  5   Notary Last Name          14713 non-null  object
#  6   Sales Date                14713 non-null  object
#  7   Sellers First Name        14713 non-null  object
#  8   Sellers Last Name         14701 non-null  object
#  9   Sellers County of Origin  14708 non-null  object
#  10  Sellers State of Origin   14711 non-null  object
#  11  Representing Seller       14577 non-null  object
#  12  Relationship to Seller    14574 non-null  object
#  13  Buyers First Name         14712 non-null  object
#  14  Buyers Last Name          14676 non-null  object
#  15  Buyers County of Origin   14711 non-null  object
#  16  Buyers State of Origin    14710 non-null  object
#  17  Representing Buyer        14405 non-null  object
#  18  Relationship to Buyer     14403 non-null  object
#  19  Slave Name                14713 non-null  object
#  20  Sex                       14703 non-null  object
#  21  Age                       14713 non-null  object
#  22  Color                     14646 non-null  object
#  23  Occupation                14705 non-null  object
#  24  Family Relationship       14707 non-null  object
#  25  Name Child 1              14325 non-null  object
#  26  Sex Child 1               14314 non-null  object
#  27  Age Child 1               14315 non-null  object
#  28  Name Child 2              14281 non-null  object
#  29  Sex Child 2               14281 non-null  object
#  30  Age Child 2               14281 non-null  object
#  31  Name Child 3              14263 non-null  object
#  32  Sex Child 3               14263 non-null  object
#  33  Age Child 3               14264 non-null  object
#  34  Name Child 4              14261 non-null  object
#  35  Sex Child 4               14261 non-null  object
#  36  Age Child 4               14261 non-null  object
#  37  Name Child 5              14260 non-null  object
#  38  Sex Child 5               14260 non-null  object
#  39  Age Child 5               14260 non-null  object
#  40  Name Child 6              14260 non-null  object
#  41  Sex Child 6               14260 non-null  object
#  42  Age Child 6               14260 non-null  object
#  43  Name Child 7              14260 non-null  object
#  44  Sex Child 7               14260 non-null  object
#  45  Age Child 7               14260 non-null  object
#  46  Name Child 8              14260 non-null  object
#  47  Sex Child 8               14255 non-null  object
#  48  Age Child 8               14251 non-null  object
#  49  Guaranteed                14693 non-null  object
#  50  Notes on Guarantee        12206 non-null  object
#  51  Number of Total Slaves    14713 non-null  int64
#  52  Number of Adult Slaves    14713 non-null  int64
#  53  Number of Child Slaves    14713 non-null  int64
#  54  Number of Prices          14713 non-null  int64
#  55  Price                     12207 non-null  object
#  56  Payment Method            9646 non-null   object
#  57  Payment flag              2535 non-null   object
#  58  DUMMY credit              14713 non-null  int64
#  59  Down Payment              2995 non-null   object
#  60  mthcred                   3024 non-null   object
#  61  Interest Rate             3023 non-null   object
#  62  Discount Rate             14659 non-null  float64
#  63  predicted rate            14659 non-null  float64
#  64  Calculations              114 non-null    float64
#  65  Ratio                     114 non-null    float64
#  66  PresentValue              3026 non-null   object
#  67  DUMMY omission            14713 non-null  int64
#  68  Reason for Omission       4176 non-null   object
#  69  Comments                  1758 non-null   object
#  70  DUMMY Estate Sale         474 non-null    float64
# dtypes: float64(5), int64(8), object(58)
# memory usage: 8.0+ MB

# %% [markdown]
# # Cleaning up data
# Dropping entries marked as omitted by the researchers and also the few entries missing vital information. I can't really figure out how the previous corgis set determined what entries to drop - it doesn't seem to be by the ommissions flag or by too much info missing.

# %%
df = df[ df["DUMMY omission"] == 0 ]
df = df[df["Discount Rate"].notna()]
df = df[df["predicted rate"].notna()]
df = df[df["Price"].notna()]
df.drop_duplicates()
df.head()
#df = df[ df[""].notna()]
# Out:
#    ID number  Conveyance Page Researcher Notary First Name Notary Last Name  \
# 0          1          70  348         MS       John French           Coffey
# 1          2          70  349         MS           William          Shannon
# 2          3          70  351         MS     Edward George       Gottschalk
# 3          4          70  352         MS        Paul Emile         Laresche
# 4          5          70  352         MS            George        Rareshide
#
#   Sales Date Sellers First Name Sellers Last Name Sellers County of Origin  \
# 0  10/6/1856           Benjamin            Screws                        .
# 1  10/7/1856           Santiago          Galseran              New Orleans
# 2  10/1/1856             Pierre             Macou              New Orleans
# 3  10/8/1856  Benjamin Franklin              Irby                  Vanzand
# 4  10/8/1856            Richard            Condon              New Orleans
#
#    ... Interest Rate Discount Rate predicted rate Calculations Ratio  \
# 0  ...           NaN      0.006027        0.07477          NaN   NaN
# 1  ...           NaN      0.006027        0.07477          NaN   NaN
# 2  ...           NaN      0.006027        0.07477          NaN   NaN
# 3  ...           NaN      0.006027        0.07477          NaN   NaN
# 4  ...           NaN      0.006027        0.07477          NaN   NaN
#
#   PresentValue DUMMY omission Reason for Omission Comments DUMMY Estate Sale
# 0          NaN              0                 NaN      NaN               NaN
# 1          NaN              0                 NaN      NaN               NaN
# 2          NaN              0                 NaN      NaN               NaN
# 3          NaN              0                 NaN      NaN               NaN
# 4          NaN              0                 NaN      NaN               NaN
#
# [5 rows x 71 columns]

# %%
#Copying over data to new dataframe
new_df = df[['Sales Date', 'Slave Name', 'Sex', 'Age', 'Color', 'Buyers County of Origin', 'Buyers State of Origin', 
            'Sellers County of Origin','Sellers State of Origin','Price', 'Payment Method', 
             'Number of Total Slaves','Number of Adult Slaves', 'Number of Child Slaves',
            'Discount Rate', 'predicted rate', 'Number of Prices']].copy()

#Name reformatting

#If they don't have a last name, usually a company name. Get rid of dot placeholder.
df.replace({'Sellers Last Name': {'.':''}},inplace=True)
df.replace({'Buyers Last Name': {'.':''}},inplace=True)

#Concatenate first and last names
new_df['Buyers Full Name'] = df['Buyers First Name'] + ' ' + df['Buyers Last Name']
new_df['Sellers Full Name'] = df['Sellers First Name'] + ' ' + df['Sellers Last Name']


#Change time to datetime format for easy sorting, separate times
dti = pd.DatetimeIndex(df['Sales Date'])
new_df['Sales Date'] = dti
new_df['Sales Year'] = dti.year 
new_df['Sales Month'] = dti.month
new_df['Sales Day'] = dti.day

#Replace all dot placeholders and NaNs with 'Unknown'
new_df.replace('.','Unknown',inplace=True)
new_df.replace(np.nan ,'Unknown',inplace=True )

#Fully written out gender
new_df.replace({'Sex': {'M' :'Male', 'F' : 'Female'} },inplace=True )

#Rounding since some of these floats are really long
new_df = new_df.round({'Discount Rate': 8, 'predicted rate': 8})

new_df.head()
# Out:
#   Sales Date Slave Name     Sex Age    Color Buyers County of Origin  \
# 0 1856-10-06   Shadrack    Male  40  Unknown                 Unknown
# 1 1856-10-07       Jane  Female  44    Negro             New Orleans
# 2 1856-10-01      Helen  Female  24    Negro             New Orleans
# 3 1856-10-08       Jeff    Male  23    Negro               Jefferson
# 4 1856-10-08       John    Male  12    Negro             New Orleans
#
#   Buyers State of Origin Sellers County of Origin Sellers State of Origin  \
# 0                Unknown                  Unknown                      AL
# 1                     LA              New Orleans                      LA
# 2                     LA              New Orleans                      LA
# 3                     LA                  Vanzand                      TX
# 4                     LA              New Orleans                      LA
#
#     Price  ... Number of Adult Slaves  Number of Child Slaves  Discount Rate  \
# 0   650.0  ...                      1                       0       0.006027
# 1   550.0  ...                      1                       0       0.006027
# 2  1000.0  ...                      1                       0       0.006027
# 3  1400.0  ...                      1                       0       0.006027
# 4   700.0  ...                      1                       0       0.006027
#
#    predicted rate  Number of Prices    Buyers Full Name  \
# 0         0.07477                 1        Maria Hopson
# 1         0.07477                 1  Peyton N. Reynolds
# 2         0.07477                 1    Heloise Bagneris
# 3         0.07477                 1   Francis Dugue Jr.
# 4         0.07477                 1      Anthony O'Dowd
#
#         Sellers Full Name Sales Year Sales Month  Sales Day
# 0         Benjamin Screws       1856          10          6
# 1       Santiago Galseran       1856          10          7
# 2            Pierre Macou       1856          10          1
# 3  Benjamin Franklin Irby       1856          10          8
# 4          Richard Condon       1856          10          8
#
# [5 rows x 22 columns]

# %% [markdown]
# # Re-ordering
# Sorting rows by date and also column names

# %%
#Column name order
columnsTitles = ['Sales Date',
                 'Sales Year',
                 'Sales Month',
                 'Sales Day',
                 'Slave Name', 
                 'Sex', 
                 'Age', 
                 'Color', 
                 'Sellers Full Name',
                 'Sellers County of Origin',
                 'Sellers State of Origin', 
                 'Buyers Full Name',
                 'Buyers County of Origin', 
                 'Buyers State of Origin', 
                 'Price', 
                 'Payment Method', 
                 'Number of Total Slaves',
                 'Number of Adult Slaves',
                 'Number of Child Slaves',
                 'Number of Prices',
                 'Discount Rate',
                 'predicted rate', ]

new_df = new_df.reindex(columns=columnsTitles)

#Set index to sales date and reorder by date
new_df.set_index("Sales Date", drop=True, append=False, inplace=True)
new_df = new_df.sort_values(by="Sales Date")

new_df.head(10)
# Out:
#             Sales Year  Sales Month  Sales Day    Slave Name     Sex Age  \
# Sales Date
# 1856-05-03        1856            5          3          Rose  Female  21
# 1856-10-01        1856           10          1         Eliza  Female  30
# 1856-10-01        1856           10          1         Helen  Female  24
# 1856-10-01        1856           10          1         Green    Male  30
# 1856-10-01        1856           10          1     Catherine  Female  32
# 1856-10-01        1856           10          1          Jane  Female  13
# 1856-10-02        1856           10          2  Mary/ Louise  Female  35
# 1856-10-02        1856           10          2       Rosalie  Female  37
# 1856-10-04        1856           10          4         Hayes    Male  35
# 1856-10-04        1856           10          4         Maria  Female  23
#
#                      Color                    Sellers Full Name  \
# Sales Date
# 1856-05-03           Negro  Josephe Marcel, Anais Gordain Braud
# 1856-10-01         Unknown                     John S. Maunsell
# 1856-10-01           Negro                         Pierre Macou
# 1856-10-01         Mulatto                   John  Caldwell Jr.
# 1856-10-01  Creole Mulatto     Marie Jeanne Victoire Dubertrand
# 1856-10-01           Negro              William Jackson Maynard
# 1856-10-02    Creole Negro                       Claude Dolbeau
# 1856-10-02           Negro                      Felicie Dumaine
# 1856-10-04           Negro                           Mary Doyle
# 1856-10-04         Mulatto               Rosslynne Cumming Vass
#
#            Sellers County of Origin Sellers State of Origin  ...  \
# Sales Date                                                   ...
# 1856-05-03                St. James                      LA  ...
# 1856-10-01              New Orleans                      LA  ...
# 1856-10-01              New Orleans                      LA  ...
# 1856-10-01              New Orleans                      LA  ...
# 1856-10-01              New Orleans                      LA  ...
# 1856-10-01              New Orleans                      LA  ...
# 1856-10-02              New Orleans                      LA  ...
# 1856-10-02              New Orleans                      LA  ...
# 1856-10-04              New Orleans                      LA  ...
# 1856-10-04              New Orleans                      LA  ...
#
#            Buyers County of Origin Buyers State of Origin   Price  \
# Sales Date
# 1856-05-03             New Orleans                     LA   850.0
# 1856-10-01             New Orleans                     LA   925.0
# 1856-10-01             New Orleans                     LA  1000.0
# 1856-10-01             New Orleans                     LA   900.0
# 1856-10-01             New Orleans                     LA   875.0
# 1856-10-01             New Orleans                     LA   812.0
# 1856-10-02             New Orleans                     LA   500.0
# 1856-10-02             New Orleans                     LA   700.0
# 1856-10-04             New Orleans                     LA   750.0
# 1856-10-04             New Orleans                     LA  1650.0
#
#              Payment Method Number of Total Slaves  Number of Adult Slaves  \
# Sales Date
# 1856-05-03             Cash                      1                       1
# 1856-10-01  Cash and Credit                      1                       1
# 1856-10-01             Cash                      1                       1
# 1856-10-01             Cash                      1                       1
# 1856-10-01             Cash                      1                       1
# 1856-10-01             Cash                      1                       1
# 1856-10-02  Cash and Credit                      1                       1
# 1856-10-02  Cash and Credit                      1                       1
# 1856-10-04             Cash                      1                       1
# 1856-10-04             Cash                      1                       1
#
#             Number of Child Slaves  Number of Prices  Discount Rate  \
# Sales Date
# 1856-05-03                       0                 1       0.006027
# 1856-10-01                       0                 1       0.005791
# 1856-10-01                       0                 1       0.006027
# 1856-10-01                       0                 1       0.006027
# 1856-10-01                       0                 1       0.006027
# 1856-10-01                       0                 1       0.006027
# 1856-10-02                       0                 1       0.005791
# 1856-10-02                       0                 1       0.005791
# 1856-10-04                       0                 1       0.006027
# 1856-10-04                       0                 1       0.006027
#
#             predicted rate
# Sales Date
# 1856-05-03        0.074770
# 1856-10-01        0.071746
# 1856-10-01        0.074770
# 1856-10-01        0.074770
# 1856-10-01        0.074770
# 1856-10-01        0.074770
# 1856-10-02        0.071746
# 1856-10-02        0.071746
# 1856-10-04        0.074770
# 1856-10-04        0.074770
#
# [10 rows x 21 columns]

# %% [markdown]
# # Exporting
# Export to csv without column names

# %%
new_df.to_csv('slavery-corgis.csv', sep=',' ,header=False)
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 10514 entries, 1856-05-03 to 1861-09-03
# Data columns (total 21 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Sales Year                10514 non-null  int64
#  1   Sales Month               10514 non-null  int64
#  2   Sales Day                 10514 non-null  int64
#  3   Slave Name                10514 non-null  object
#  4   Sex                       10514 non-null  object
#  5   Age                       10514 non-null  object
#  6   Color                     10514 non-null  object
#  7   Sellers Full Name         10514 non-null  object
#  8   Sellers County of Origin  10514 non-null  object
#  9   Sellers State of Origin   10514 non-null  object
#  10  Buyers Full Name          10514 non-null  object
#  11  Buyers County of Origin   10514 non-null  object
#  12  Buyers State of Origin    10514 non-null  object
#  13  Price                     10514 non-null  float64
#  14  Payment Method            10514 non-null  object
#  15  Number of Total Slaves    10514 non-null  int64
#  16  Number of Adult Slaves    10514 non-null  int64
#  17  Number of Child Slaves    10514 non-null  int64
#  18  Number of Prices          10514 non-null  int64
#  19  Discount Rate             10514 non-null  float64
#  20  predicted rate            10514 non-null  float64
# dtypes: float64(3), int64(7), object(11)
# memory usage: 1.8+ MB
