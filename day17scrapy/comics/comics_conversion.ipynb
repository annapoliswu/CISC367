# %%
import pandas as pd

df = pd.read_json("comics.json")
df['pagecount'] = pd.to_numeric( df['pagecount'] ,downcast='integer')
df = df.replace("", "Unknown")

df.to_csv("comics.csv", index=False)
# Out:
#                                                 title  \
# 0                       100 Bullets Omnibus Vol 01 HC
# 1                  Absolute Superman Batman HC Vol 02
# 2                  Absolute Superman Batman HC Vol 01
# 3   Absolute All-Star Batman & Robin the Boy Wonde...
# 4                   Absolute Batman Haunted Knight HC
# 5                         100 Bullets TP Book 05 (MR)
# 6                        Absolute Authority HC Vol 01
# 7                         100 Bullets TP Book 04 (MR)
# 8               Absolute Green Lantern Green Arrow HC
# 9                  Absolute Superman Batman HC Vol 01
# 10                                       52 TP Vol 02
# 11                     Absolute Sandman Vol 1 HC (MR)
# 12                   Absolute Preacher HC Vol 03 (MR)
# 13                              Absolute Planetary HC
# 14           Aquaman the Search for Mera Deluxe Ed HC
# 15           Aquaman TP Vol 01 the Drowning (Rebirth)
# ...
